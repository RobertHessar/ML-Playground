# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt

# %%
Ames = pd.read_csv('AmesHousing.csv')

# %%
rows, columns = Ames.shape

print(f"The dataset made of {rows} properties described by {columns} features.")
# Out:
# The dataset made of 2930 properties described by 82 features.

# %%
# Determine the data type for each feature
data_types = Ames.dtypes
 
# Tally the total by data type
type_counts = data_types.value_counts()
 
print(type_counts)
# Out:
# object     43
# int64      28
# float64    11
# Name: count, dtype: int64

# %%
# Determine the data type for each feature
data_types = Ames.dtypes
 
# View a few datatypes from the dataset (first and last 5 features)
print(data_types)
# Out:
# Order               int64
# PID                 int64
# MS SubClass         int64
# MS Zoning          object
# Lot Frontage      float64
#                    ...
# Mo Sold             int64
# Yr Sold             int64
# Sale Type          object
# Sale Condition     object
# SalePrice           int64
# Length: 82, dtype: object

# %%
# Create a DataFrame with various types of missing values
df = pd.DataFrame({
    'A': [1, 2, np.nan, 4, 5],
    'B': ['a', 'b', None, 'd', 'e'],
    'C': [np.nan, np.nan, np.nan, np.nan, np.nan],
    'D': [1, 2, 3, 4, 5]
})

# Use isnull() to identify missing values
missing_data = df.isnull().sum()

print(df)
print()
print(missing_data)
# Out:
#      A     B   C  D
# 0  1.0     a NaN  1
# 1  2.0     b NaN  2
# 2  NaN  None NaN  3
# 3  4.0     d NaN  4
# 4  5.0     e NaN  5
#
# A    1
# B    1
# C    5
# D    0
# dtype: int64

# %%
# Calculating the percentage of missing values for each column
missing_data = Ames.isnull().sum()
missing_percentage = (missing_data / len(Ames)) * 100

# Combining the counts and percentages into a DataFrame for better visualization
missing_info = pd.DataFrame({'Missing Values': missing_data, 'Percentage': missing_percentage})
 
# Sorting the DataFrame by the percentage of missing values in descending order
missing_info = missing_info.sort_values(by='Percentage', ascending=False)
 
# Display columns with missing values
print(missing_info[missing_info['Missing Values'] > 0])
# Out:
#                 Missing Values  Percentage
# Pool QC                   2917   99.556314
# Misc Feature              2824   96.382253
# Alley                     2732   93.242321
# Fence                     2358   80.477816
# Mas Vnr Type              1775   60.580205
# Fireplace Qu              1422   48.532423
# Lot Frontage               490   16.723549
# Garage Cond                159    5.426621
# Garage Finish              159    5.426621
# Garage Yr Blt              159    5.426621
# Garage Qual                159    5.426621
# Garage Type                157    5.358362
# Bsmt Exposure               83    2.832765
# BsmtFin Type 2              81    2.764505
# Bsmt Qual                   80    2.730375
# Bsmt Cond                   80    2.730375
# BsmtFin Type 1              80    2.730375
# Mas Vnr Area                23    0.784983
# Bsmt Full Bath               2    0.068259
# Bsmt Half Bath               2    0.068259
# BsmtFin SF 1                 1    0.034130
# Garage Cars                  1    0.034130
# Electrical                   1    0.034130
# Total Bsmt SF                1    0.034130
# Bsmt Unf SF                  1    0.034130
# BsmtFin SF 2                 1    0.034130
# Garage Area                  1    0.034130

# %%
(missing_data / len(Ames)) * 100
# Out:
# Order              0.000000
# PID                0.000000
# MS SubClass        0.000000
# MS Zoning          0.000000
# Lot Frontage      16.723549
#                     ...
# Mo Sold            0.000000
# Yr Sold            0.000000
# Sale Type          0.000000
# Sale Condition     0.000000
# SalePrice          0.000000
# Length: 82, dtype: float64

# %%
msno.matrix(Ames, sparkline=False, fontsize=20)
plt.show()

# %%
# Calculating the percentage of missing values for each column
missing_data = Ames.isnull().sum()
missing_percentage = (missing_data / len(Ames)) * 100
 
# Combining the counts and percentages into a DataFrame for better visualization
missing_info = pd.DataFrame({'Missing Values': missing_data, 'Percentage': missing_percentage})
 
# Sort the DataFrame columns by the percentage of missing values
sorted_df = Ames[missing_info.sort_values(by='Percentage', ascending=False).index]
 
# Select the top 15 columns with the most missing values
top_15_missing = sorted_df.iloc[:, :15]
 
#Visual with missingno
msno.bar(top_15_missing)
plt.show()

# %%
top_15_missing
# Out:
#      Pool QC Misc Feature Alley  Fence Mas Vnr Type Fireplace Qu  \
# 0        NaN          NaN   NaN    NaN        Stone           Gd
# 1        NaN          NaN   NaN  MnPrv          NaN          NaN
# 2        NaN         Gar2   NaN    NaN      BrkFace          NaN
# 3        NaN          NaN   NaN    NaN          NaN           TA
# 4        NaN          NaN   NaN  MnPrv          NaN           TA
# ...      ...          ...   ...    ...          ...          ...
# 2925     NaN          NaN   NaN  GdPrv          NaN          NaN
# 2926     NaN          NaN   NaN  MnPrv          NaN          NaN
# 2927     NaN         Shed   NaN  MnPrv          NaN          NaN
# 2928     NaN          NaN   NaN    NaN          NaN           TA
# 2929     NaN          NaN   NaN    NaN      BrkFace           TA
#
#       Lot Frontage Garage Cond Garage Finish  Garage Yr Blt Garage Qual  \
# 0            141.0          TA           Fin         1960.0          TA
# 1             80.0          TA           Unf         1961.0          TA
# 2             81.0          TA           Unf         1958.0          TA
# 3             93.0          TA           Fin         1968.0          TA
# 4             74.0          TA           Fin         1997.0          TA
# ...            ...         ...           ...            ...         ...
# 2925          37.0          TA           Unf         1984.0          TA
# 2926           NaN          TA           Unf         1983.0          TA
# 2927          62.0         NaN           NaN            NaN         NaN
# 2928          77.0          TA           RFn         1975.0          TA
# 2929          74.0          TA           Fin         1993.0          TA
#
#      Garage Type Bsmt Exposure BsmtFin Type 2 Bsmt Qual
# 0         Attchd            Gd            Unf        TA
# 1         Attchd            No            LwQ        TA
# 2         Attchd            No            Unf        TA
# 3         Attchd            No            Unf        TA
# 4         Attchd            No            Unf        Gd
# ...          ...           ...            ...       ...
# 2925      Detchd            Av            Unf        TA
# 2926      Attchd            Av            ALQ        Gd
# 2927         NaN            Av            Unf        Gd
# 2928      Attchd            Av            LwQ        Gd
# 2929      Attchd            Av            Unf        Gd
#
# [2930 rows x 15 columns]

# %%
Ames[missing_info.sort_values(by='Percentage', ascending=False).index]
# Out:
#      Pool QC Misc Feature Alley  Fence Mas Vnr Type Fireplace Qu  \
# 0        NaN          NaN   NaN    NaN        Stone           Gd
# 1        NaN          NaN   NaN  MnPrv          NaN          NaN
# 2        NaN         Gar2   NaN    NaN      BrkFace          NaN
# 3        NaN          NaN   NaN    NaN          NaN           TA
# 4        NaN          NaN   NaN  MnPrv          NaN           TA
# ...      ...          ...   ...    ...          ...          ...
# 2925     NaN          NaN   NaN  GdPrv          NaN          NaN
# 2926     NaN          NaN   NaN  MnPrv          NaN          NaN
# 2927     NaN         Shed   NaN  MnPrv          NaN          NaN
# 2928     NaN          NaN   NaN    NaN          NaN           TA
# 2929     NaN          NaN   NaN    NaN      BrkFace           TA
#
#       Lot Frontage Garage Cond Garage Finish  Garage Yr Blt  ... Exterior 2nd  \
# 0            141.0          TA           Fin         1960.0  ...      Plywood
# 1             80.0          TA           Unf         1961.0  ...      VinylSd
# 2             81.0          TA           Unf         1958.0  ...      Wd Sdng
# 3             93.0          TA           Fin         1968.0  ...      BrkFace
# 4             74.0          TA           Fin         1997.0  ...      VinylSd
# ...            ...         ...           ...            ...  ...          ...
# 2925          37.0          TA           Unf         1984.0  ...      HdBoard
# 2926           NaN          TA           Unf         1983.0  ...      HdBoard
# 2927          62.0         NaN           NaN            NaN  ...      Wd Shng
# 2928          77.0          TA           RFn         1975.0  ...      HdBoard
# 2929          74.0          TA           Fin         1993.0  ...      HdBoard
#
#      Exter Qual Exter Cond Foundation Heating        PID Central Air  \
# 0            TA         TA     CBlock    GasA  526301100           Y
# 1            TA         TA     CBlock    GasA  526350040           Y
# 2            TA         TA     CBlock    GasA  526351010           Y
# 3            Gd         TA     CBlock    GasA  526353030           Y
# 4            TA         TA      PConc    GasA  527105010           Y
# ...         ...        ...        ...     ...        ...         ...
# 2925         TA         TA     CBlock    GasA  923275080           Y
# 2926         TA         TA     CBlock    GasA  923276100           Y
# 2927         TA         TA      PConc    GasA  923400125           Y
# 2928         TA         TA     CBlock    GasA  924100070           Y
# 2929         TA         TA      PConc    GasA  924151050           Y
#
#       1st Flr SF  2nd Flr SF  SalePrice
# 0           1656           0     215000
# 1            896           0     105000
# 2           1329           0     172000
# 3           2110           0     244000
# 4            928         701     189900
# ...          ...         ...        ...
# 2925        1003           0     142500
# 2926         902           0     131000
# 2927         970           0     132000
# 2928        1389           0     170000
# 2929         996        1004     188000
#
# [2930 rows x 82 columns]
